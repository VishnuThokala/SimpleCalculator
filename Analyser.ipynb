# %% [markdown]
# <a href="https://colab.research.google.com/github/VishnuThokala/SimpleCalculator/blob/master/Analyser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def isDate(s):
    try:
    token,content=s.split('-')
    user,msg = content.split(':')
    try:
      date,time = token.split(',')
      month, day, year = date.split('/')
    except:
      month,day,year = "-1"
      date,time ="-1"
    return [date.strip(),time.strip(),user.strip(),msg.strip()]
  except:
    token="-1"
    msg=i
    return [token.strip(),msg.strip()]

# %%
import csv
f= open('nss.txt','r')
records=[]
for i in f:
  l=[]  
  l=isDate(i)
  if l[0] != "-1":
    records.append(l)
  else:
    k=len(records)
    if k > 1:
      records[k-1][3]+l[1]

fields=['date','time','user','msg']
filename = "whatsapp.csv"
for i in records:
  print(i)
with open(filename, 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(records)
print("done !!")
# Out:
# Streaming output truncated to the last 5000 lines.
# ['9/20/20', '7:48 PM', 'Shiva NSS', '<Media omitted>']
# ['9/20/20', '7:49 PM', 'Shiva NSS', 'Check it once']
# ['9/20/20', '7:49 PM', 'Shiva NSS', "So that we can send it to ma'am"]
# ['9/20/20', '8:09 PM', 'Srinvas Nss', '👍🏻']
# ['9/20/20', '8:09 PM', 'Srinvas Nss', '💥💥💥']
# ['9/20/20', '10:15 PM', 'Saketh Vangaala', 'Guys juzt link click chesi participate now ani click cheyandi...']
# ['9/20/20', '11:28 PM', 'Ayush NSS', 'Witness the first super in ipl 2020 it is going to start']
# ['9/20/20', '11:29 PM', 'Tharun Nss', '😂']
# ['9/20/20', '11:29 PM', 'Tharun Nss', 'Over*']
# ['9/20/20', '11:30 PM', 'Saketh Vangaala', 'Yeah...']
# ['9/20/20', '11:30 PM', 'Tharun Nss', 'Delhi ah Punjab aah🤔🙃']
# ['9/20/20', '11:31 PM', 'Saketh Vangaala', 'Punjab']
# ['9/20/20', '11:31 PM', 'Lalith NSS', 'Dc kavachu']
# ['9/20/20', '11:31 PM', 'Lalith NSS', '😀']
# ['9/20/20', '11:31 PM', 'Ayush NSS', 'DC']
# ...

# %%
import pandas as pd

ds = pd.read_csv('whatsapp.csv')
List=[]
for i in range(len(ds)):
     List.append(ds.iloc[i,2])

s=set(List)
print(len(s),s)

di={}
for i in s:
  count = 0
  di[i]=0
  for j in range(len(ds)):
    if ds.iloc[j,2] == i:
      count=count+1
  di[i]=count;
  # print(i,"has sent ", count ,"messages")
print(di)
# Out:
# 27 {'Harshitha Nss', 'Karthik Rao Surineni', 'Venkatesh NSS', 'Sai Kiran Nss', 'Rohith Nss', 'Avaneesh Nss', 'Tharun Nss', 'Shiva NSS', 'Sathwik Nss', 'Vishnu Vardhan Reddy', 'Tanuja Nss', 'Amulya NSS', 'Ayush NSS', 'Shriya Nss', 'Muddasir NSS', 'Prasanna Nss', 'Srinvas Nss', 'Meena NSS', 'Saketh Vangaala', 'Akhil Sai Nss', 'Uday NSS', 'Deedepya Nss', 'Haripriya Nss', 'Spurthi Nss', 'Lalith NSS', 'Sandhya NSS', 'Devi NSS'}
# ...

# %%
for i in di:
  f=0
  print(i)
  for j in range(len(ds)):
    if ds.iloc[j,2] == i and f==0:
        print("first msg:",ds.iloc[j,3])
        f=1
    last=ds.iloc[j,3]
  if last == '<Media omitted>':
    print('Last msg :Sticker')
  else:
    print("last msg",last)
  print(" ")
# Out:
# Harshitha Nss
# first msg: This message was deleted
# Last msg :Sticker
#
# Karthik Rao Surineni
# first msg: Parade lo okkokka row vallu okkokka topic Midha cheste ela untundhi?
# Last msg :Sticker
#
# Venkatesh NSS
# first msg: 17 topics vunnay ga...intrest batti divide avudam teams laga
# Last msg :Sticker
#
# Sai Kiran Nss
# first msg: 🙋‍♂
# Last msg :Sticker
#
# Rohith Nss
# first msg: 🤟
# Last msg :Sticker
#
# Avaneesh Nss
# first msg: You are saying about the ones who are not selected .....haa many of them didn't even know what's happened
# Last msg :Sticker
#
# Tharun Nss
# first msg: This message was deleted
# Last msg :Sticker
#
# Shiva NSS
# first msg: 😊
# Last msg :Sticker
#
# Sathwik Nss
# first msg: Hi
# Last msg :Sticker
#
# Vishnu Vardhan Reddy
# first msg: For tomorrow pre works those who are coming update the list
# Last msg :Sticker
#
# Tanuja Nss
# first msg: 🙋🏽‍♀
# Last msg :Sticker
#
# Amulya NSS
# first msg: Haa avunu
# Last msg :Sticker
#
# Ayush NSS
# ...

# %%
print("First highest and second highest used words with counts:")
for i in di:
  f=0
  print(i)
  l=[]
  for j in range(len(ds)):
    if ds.iloc[j,2] == i:
      s=ds.iloc[j,3]
      for p in s.split(' '):
        l.append(p)
  
  map={}
  for a in l:
    if a not in map:
      map[a]=0
    else:
      map[a]=map[a]+1
  
  List=sorted(map.items(), key = lambda kv:(kv[1], kv[0]))
  if List[len(List)-1][0]=='omitted>' or  List[len(List)-1][0] == '<Media':
    print('Media File or Sticker')
  else:
    print(List[len(List)-1])
  if List[len(List)-2][0]=='omitted>' or  List[len(List)-2][0] == '<Media':
    print('Media File or Sticker')
  else:
    print(List[len(List)-2])
  print('')
# Out:
# First highest and second highest used words with counts:
# Harshitha Nss
# ('the', 24)
# ('i', 22)
#
# Karthik Rao Surineni
# ('the', 17)
# Media File or Sticker
#
# Venkatesh NSS
# ('ra', 53)
# Media File or Sticker
#
# Sai Kiran Nss
# ('ra', 64)
# ('👍', 38)
#
# Rohith Nss
# Media File or Sticker
# Media File or Sticker
#
# Avaneesh Nss
# ('ra', 140)
# ('the', 132)
#
# Tharun Nss
# Media File or Sticker
# Media File or Sticker
#
# Shiva NSS
# Media File or Sticker
# Media File or Sticker
#
# Sathwik Nss
# Media File or Sticker
# Media File or Sticker
#
# Vishnu Vardhan Reddy
# ('to', 95)
# ('the', 94)
#
# Tanuja Nss
# Media File or Sticker
# Media File or Sticker
#
# Amulya NSS
# ('the', 33)
# ('👍', 32)
#
# Ayush NSS
# ('I', 26)
# ('the', 25)
#
# Shriya Nss
# ('Haa', 41)
# ('kdha', 40)
#
# Muddasir NSS
# ('ra', 198)
# ('the', 97)
#
# Prasanna Nss
# ('the', 62)
# ('Okay', 54)
#
# Srinvas Nss
# Media File or Sticker
# Media File or Sticker
#
# Meena NSS
# ('the', 85)
# ('ani', 71)
#
# ...

# %%
l=[]
for j in range(len(ds)):
    s=ds.iloc[j,3]
    for p in s.split(' '):
          l.append(p) 
map={}
for a in l:
  if a not in map:
    map[a]=0
  else:
    map[a]=map[a]+1
text=[]
List=sorted(map.items(), key = lambda kv:(kv[1], kv[0]))
for x in range(80):
  if List[len(List)-3-x][0]=='omitted>' or  List[len(List)-3-x][0] == '<Media':
    text.append('Media File or Sticker')
  else:
    text.append(List[len(List)-3-x][0])
print(text)
# Out:
# ['the', 'to', 'ra', 'lo', 'meet', 'ki', 'list', 'ani', 'Ha', '👍', 'was', 'I', 'message', 'This', 'ga', 'deleted', 'Arey', 'Happy', 'and', 'are', 'we', 'Haa', 'kuda', 'Update', 'Ok', 'who', 'is', 'for', 'kada', 'Okay', 'join', 'of', 'Guys', 'in', 'a', 'Yeah', '', '😂', 'birthday', 'it', 'em', 'attend', 'have', '😂😂', 'be', 'ante', 'you', 'that', 'time', 'this', 'seniors', 'guys', 'will', 'update', 'Hello', 'with', 'vallu', 'can', 'attending', 'start', 'ni', 'not', '?', 'Birthday', 'manam', 'inka', 'anna', 'juniors', 'ok', 'on', 'No', 'about', 'i', 'anta', '✌️', 'raa', 'their', 'msg', 'chesi', 'And']

# %%
user_msg_counts = ds['user'].value_counts() 
print(user_msg_counts)
# Out:
# Spurthi Nss             2337
# Saketh Vangaala         2107
# Muddasir NSS            1699
# Devi NSS                1654
# Shiva NSS               1561
# Avaneesh Nss            1532
# Sandhya NSS             1412
# Tharun Nss              1372
# Sathwik Nss             1331
# Rohith Nss              1298
# Meena NSS               1081
# Vishnu Vardhan Reddy    1071
# Deedepya Nss            1068
# Shriya Nss              1010
# Prasanna Nss             991
# Srinvas Nss              864
# Akhil Sai Nss            820
# Sai Kiran Nss            767
# Venkatesh NSS            753
# Haripriya Nss            516
# Amulya NSS               434
# Lalith NSS               411
# Tanuja Nss               370
# Harshitha Nss            365
# Uday NSS                 234
# Ayush NSS                212
# Karthik Rao Surineni     117
# Name: user, dtype: int64

# %%
print('user vs count of messages')
user_msg_counts.plot.barh()
# Out:
# user vs count of messages

# %%
print('user vs count of messages')
print('Top 10 users ')
top_10_user_msg_counts = user_msg_counts.head(10) 
print(top_10_user_msg_counts.plot.barh())
# Out:
# user vs count of messages
# Top 10 users
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print('user vs count of messages')
print('Bottom 10 users ')
least_10_user_msg_counts = user_msg_counts.tail(10) 
least_10_user_msg_counts.plot.barh()
# Out:
# user vs count of messages
# Bottom 10 users

# %%
print('user vs media_messages  or stickers')
media_messages_ds = ds[ds['msg'] == '<Media omitted>']
user_media_messages_counts = media_messages_ds['user'].value_counts() 
top_10_user_media_messages_counts = user_media_messages_counts.head(27) 
top_10_user_media_messages_counts.plot.barh()
# Out:
# user vs media_messages  or stickers

# %%
date_counts = ds['date'].value_counts() 
date_counts.head(20).plot.barh()

# %%
date_counts = ds['time'].value_counts() 
date_counts.head(20).plot.barh()

# %%
s=""
for i in text:
  s=s+i+" "
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");
# Import package
from wordcloud import WordCloud, STOPWORDS

wordcloud = WordCloud(width = 400, height = 400, random_state=1, background_color='white', stopwords = STOPWORDS).generate(s)
# Plot
plot_cloud(wordcloud)
